# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HOpG8KCwJWz71KtyJ1X8")
project = rf.workspace("imes-workspace").project("traffic-light-v9orl-rs87h")
version = project.version(1)
dataset = version.download("yolov8")

# %%
model = YOLO("yolov8n.pt")

# %%
model1.train(data='/content/traffic-light-3/data.yaml', epochs=10)

# %%
from ultralytics import YOLO
model = YOLO("best.pt")

results = model.predict(
    source="test_proj.mp4",                  
    save=True,                  
    project="video_results",    
    name="test_run"             
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1019) C:\Users\User\test_proj.mp4: 384x640 1 Red, 85.2ms
# video 1/1 (frame 2/1019) C:\Users\User\test_proj.mp4: 384x640 1 Red, 16.5ms
# video 1/1 (frame 3/1019) C:\Users\User\test_proj.mp4: 384x640 1 Red, 15.5ms
# video 1/1 (frame 4/1019) C:\Users\User\test_proj.mp4: 384x640 2 Reds, 15.0ms
# video 1/1 (frame 5/1019) C:\Users\User\test_proj.mp4: 384x640 1 Red, 15.6ms
# ...
